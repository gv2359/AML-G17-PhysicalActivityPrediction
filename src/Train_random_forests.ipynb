# %%
import numpy as np 
import pandas as pd 
import matplotlib.pylab as plt
import math
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import xgboost as XGBClassifier

# %%
df = pd.read_csv('../data/final_data.csv')
df.shape
# Out:
# (1942872, 32)

# %%
df.head()
# Out:
#    activity_id  heart-rate  IMU_hand_temp  IMU_hand_acc_x_sc16  \
# 0            1       100.0         30.375              2.21530
# 1            1       100.0         30.375              2.29196
# 2            1       100.0         30.375              2.29090
# 3            1       100.0         30.375              2.21800
# 4            1       100.0         30.375              2.30106
#
#    IMU_hand_acc_y_sc16  IMU_hand_acc_z_sc16  IMU_hand_gyro_x  IMU_hand_gyro_y  \
# 0              8.27915              5.58753        -0.004750         0.037579
# 1              7.67288              5.74467        -0.171710         0.025479
# 2              7.14240              5.82342        -0.238241         0.011214
# 3              7.14365              5.89930        -0.192912         0.019053
# 4              7.25857              6.09259        -0.069961        -0.018328
#
#    IMU_hand_gyro_z  IMU_hand_mag_x  ...  IMU_ankle_temp  IMU_ankle_acc_x_sc16  \
# ...

# %%
y = df['activity_id']
X =  df.drop('activity_id', axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
rf_params = [{"n_estimators":[50,100,200,300,500],"max_depth":[5,10,15,20,25]}]

# %%
randomForest_grid = GridSearchCV(RandomForestClassifier(random_state=42),
                                        param_grid=rf_params,
                                        return_train_score=True)
randomForest_grid.fit(X_train,y_train)

# %%
rf_score = randomForest_grid.score(X_test,y_test)
rf_score

# %%
xgb_params = {"max_depth":[4,7,10],"learning_rate":[0.01,0.1,0.4],"subsample":[0.6,0.8,1.0]}

xgboost_grid = GridSearchCV(XGBClassifier(random_state=42),
                                        param_grid=xgb_params,
                                        return_train_score=True)
xgboost_grid.fit(X_train,y_train)

# %%
xgb_score = xgboost_grid.score(X_test,y_test)
xgb_score
